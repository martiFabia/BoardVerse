# %% [markdown]
# # 3. Retrieve tournaments

# %% [markdown]
# Requirements

# %%
# %pip install -r ../requirements.txt -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Imports

# %%
import os
import time

import pandas as pd
import numpy as np

import requests
import xml.etree.ElementTree as ET
import json
from tqdm import tqdm
import logging
from bs4 import BeautifulSoup

import inflect
p = inflect.engine()

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %% [markdown]
# Logging configuration

# %%
logging.basicConfig(level=logging.WARNING, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger()

# %% [markdown]
# Constants

# %%
# Repositories creation
DATA_DIR = os.path.join("..", "data")
TEMP_DIR = os.path.join(DATA_DIR, "temp")
RAW_DIR = os.path.join(DATA_DIR, "raw")

os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(TEMP_DIR, exist_ok=True)
os.makedirs(RAW_DIR, exist_ok=True)

# %%
# Files
TOP_GAMES_LIST_FILE = os.path.join(DATA_DIR, "boardgames_ranks.csv")
USERNAMES_FILE = os.path.join(TEMP_DIR, "usernames.json")
TOURNAMENTS_FILE = os.path.join(RAW_DIR, "tournaments.json")

# %%
# General download parameters
BACKUP_PERIOD = 100 # Frequency of data backup
REQUEST_DELAY = 0.5    # Delay between requests
MAX_RETRIES = 5 # Max number of retries for a request

# %%
OVERWRITE = False    # If True, the existing files will be overwritten

# %%
# Game interval definition
GAME_RANK_MIN = 1   # Rank of the first game to download
GAME_RANK_MAX = 2000    # Rank of the last game to download
GAME_NUM = GAME_RANK_MAX - GAME_RANK_MIN + 1    # Number of games to download

# %%
# Specific download parameters
MAX_TOURNAMENTS_NUM = 10 # Max number of tournaments to download for each game and each status

# %%
# URLs
BGA_BASE_URL = "https://boardgamearena.com"

# %% [markdown]
# Utility functions

# %%
def save_to_json(data, filename):
    """
    Save data to a JSON file.

    Parameters:
    data (any): The data to be saved to the JSON file. This can be any data type that is serializable to JSON.
    filename (str): The name of the file where the data will be saved.

    Returns:
    None
    """
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

# %%
def append_to_json(new_data, filename):
    """
    Adds new data to an existing JSON file without duplicates.

        new_data (list): The new data to add.
        filename (str): The name of the JSON file.
    """
    # Read existing data from the file.
    try:
        with open(filename, "r", encoding="utf-8") as f:
            existing_data = json.load(f)
    except FileNotFoundError:
        existing_data = []

    # Combine the existing data with the new data and remove duplicates.
    combined_data = {json.dumps(item, sort_keys=True): item for item in existing_data + new_data}.values()

    # Save the combined data back to the file.
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(list(combined_data), f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## 1.1 Functions

# %% [markdown]
# Normalize boardgame name to use in URL

# %%
def normalize_gamename(gamename):
    """
    Normalizes the name of a game by removing spaces and special characters, and converting everything to lowercase.
    Replaces numbers with their corresponding words in English.

        Args:
            gamename (str): The original name of the game.

        Returns:
            str: The normalized game name.
    """
    normalized_name = ''.join(e for e in gamename if e.isalnum() or e.isspace()).lower()
    words = normalized_name.split()
    normalized_words = [p.number_to_words(word) if word.isdigit() else word for word in words]
    return ''.join(e for e in ''.join(normalized_words) if not e.isspace())

# %% [markdown]
# Retrieve the BGA id of a game, if it exists

# %%
def find_id_from_gamename(driver, gamename, sleep_time=0.5, max_retries=5):
    """
    Retrieve the game ID from the game name using a Selenium WebDriver.
    Args:
        driver (selenium.webdriver): The Selenium WebDriver instance used to navigate the web page.
        gamename (str): The name of the game for which the ID is to be found.
        sleep_time (float, optional): The time to wait between retries in seconds. Default is 0.5 seconds.
        max_retries (int, optional): The maximum number of retries if the request fails. Default is 5.
    Returns:
        str or None: The game ID if found, otherwise None.
    Raises:
        Exception: If an unexpected error occurs during the retrieval process.
    """
    # Build the URL for requesting the forum list
    url = f"{BGA_BASE_URL}/gamepanel?game={normalize_gamename(gamename)}"
    status_code = 500

    # Retry loop for fetching the threads from the forum
    while status_code != 200:
        # Pause briefly between retries
        time.sleep(sleep_time)  # Delay
        try:
            driver.get(url)
            break
        except Exception as e:
            # Log an error if an exception occurs
            logger.error(f"Exception occurred while retrieving {gamename}: {e}.")
            max_retries -= 1
            if max_retries == 0:
                # Log an error if retries are exhausted
                logger.error(f"Error retrieving {gamename}. Retries exhausted.")
                return None

    # Check for fatal error indicating game not found
    try:
        if driver.find_elements(By.CSS_SELECTOR, "div.fatalerror#bga_fatal_error"):
            logger.info(f'Game "{gamename}" not found.')
            return None
        # Find the id element
        id_span = driver.find_element(By.CSS_SELECTOR, '#game_id')
        game_id = id_span.get_attribute('innerHTML')
        return game_id
    except Exception as e:
        logger.error(f'Element with CSS selector "#game_id" not found for game "{gamename}" - error {e}.')
        return None

    # Log an error if the link is not found
    logger.error(f'Link for game "{gamename}" not found.')
    return None

# %% [markdown]
# Retrieve a list of tournaments ids given the related game and optional parameters

# %%
def find_tournaments_by_id(
    game_id,
    ptime=0,
    prestige=0,
    ptype=0,
    players_per_match_min=0,
    players_per_match_max=0,
    gamecateg=3,
    status="future",
    tournament_i_registered=0,
    full="true",
    max_tournaments_num=np.inf, max_posts=5, sleep_time=0.5, max_retries=5
    ):
    '''
        
    '''
    # Build the URL for requesting the tournament list
    base_url = f"{BGA_BASE_URL}/tournamentlist?d"
    params = {
        "time": ptime,
        "prestige": prestige,
        "type": ptype,
        "players_per_match_min": players_per_match_min,
        "players_per_match_max": players_per_match_max,
        "gamecateg": gamecateg,
        "status": status,
        "game": game_id,
        "tournament_i_registered": tournament_i_registered,
        "full": full
    }
    url = base_url + "&" + "&".join([f"{key}={value}" for key, value in params.items()])
    status_code = 500

    # Retry loop for fetching the threads from the forum
    while status_code != 200:
        # Pause briefly between retries
        time.sleep(sleep_time)  # Delay
        try:
            driver.get(url)
            break
        except Exception as e:
            # Log an error if an exception occurs
            logger.error(f"Exception occurred while retrieving tournaments (game_id={gamename}): {e}.")
            max_retries -= 1
            if max_retries == 0:
                # Log an error if retries are exhausted
                logger.error(f"Error retrieving tournaments (game_id={gamename}). Retries exhausted.")
                return None
    
    # Retrieve tournament list
    try:
        tournaments = driver.find_elements(By.XPATH, '//*[@id="tournament_list"]/a[*]')
    except Exception as e:
        logger.error(f'Element with CSS selector "#tournament_list" not found for game "{gamename}" - error {e}.')
        return None

    # Retrieve their ids
    tournament_ids = []
    for tournament in tournaments:
        href = tournament.get_attribute("href")
        tournament_id = href.split("id=")[-1].split("&")[0]
        tournament_ids.append(tournament_id)

    return tournament_ids if len(tournament_ids) <= max_tournaments_num else tournament_ids[:max_tournaments_num]

# %% [markdown]
# Retrieve tournament data given its ID

# %%
def fetch_tournament_data(tournament_id, status, sleep_time=0.5, max_retries=5):
    '''

    '''    
    # Build the URL for requesting the tournament page
    url = f"https://boardgamearena.com/tournament?id={tournament_id}"
    status_code = 500

    # Retry loop for fetching the threads from the forum
    while status_code != 200:
        # Pause briefly between retries
        try:
            driver.get(url)
            break
        except Exception as e:
            # Log an error if an exception occurs
            logger.error(f"Exception occurred while retrieving {gamename}: {e}.")
            max_retries -= 1
            if max_retries == 0:
                # Log an error if retries are exhausted
                logger.error(f"Error retrieving {gamename}. Retries exhausted.")
                return None
            time.sleep(sleep_time)  # Delay
    
    time.sleep(sleep_time)  # Delay

    try:
        tournament_details = {
            "id": tournament_id,
            "name": driver.find_element(By.XPATH, '//*[@id="tournament-module"]/div[3]/div/div/div[1]/div[3]/div[1]/div[2]/div[1]').get_attribute('innerHTML'),
            "type": driver.find_element(By.XPATH, '//*[@id="tournament-module"]/div[3]/div/div/div[3]/div[2]/div[1]').get_attribute('innerHTML'),
            "type_description": driver.find_element(By.XPATH, '//*[@id="tournament-module"]/div[3]/div/div/div[3]/div[2]/div[2]').get_attribute('innerHTML'),
            "status": status,
            "num_participants": driver.find_element(By.XPATH, '//*[@id="tournament-module"]/div[3]/div/div/div[1]/div[3]/div[2]/div[2]/div[2]/b').get_attribute('innerHTML'),
            "min_participants": driver.find_element(By.XPATH, '//*[@id="tournament-module"]/div[3]/div/div/div[1]/div[3]/div[2]/div[2]/div[2]/div').get_attribute('innerHTML').split(" ")[0],
            "max_participants": driver.find_element(By.XPATH, '//*[@id="tournament-module"]/div[3]/div/div/div[1]/div[3]/div[2]/div[2]/div[2]/small').get_attribute('innerHTML').split(" ")[2],
            "starting_time": None,
            "location": {
                "state": None,
                "country": None,
                "city": None
            },
            "participants": [],
            "administrator": None,
            "options": {}
        }

        # Retrieve starting time
        time_text = driver.find_element(By.XPATH, '//*[@id="tournament-module"]/div[3]/div/div/div[1]/div[3]/div[2]/div[3]/div[2]/div[1]').get_attribute('innerHTML')
        tournament_details["starting_time"] = f"{time_text.split(" ")[0]} {time_text.split(" ")[2]}"
        
        # Retrieve tournament options
        options = driver.find_elements(By.XPATH, '//*[@id="tournament-module"]/div[3]/div/div/div[3]/div[2]/div[*]')
        for option in options:
            key = option.find_element(By.XPATH, 'div[1]').get_attribute('innerHTML')
            if key == "Reputation required":
                value = option.find_element(By.XPATH, 'div[2]/span/div').get_attribute('innerHTML')
            elif key == "Time allotted to each player":
                value = option.find_element(By.XPATH, 'div[2]/span/span').get_attribute('innerHTML')
            else:
                value = option.find_element(By.XPATH, 'div[2]/span').get_attribute('innerHTML')
            tournament_details["options"][key] = value
        
    except Exception as e:
        logger.error(f"Exception occurred while retrieving tournament details: {e}")
        return None
    
    return tournament_details

# %% [markdown]
# ## 3.2 Execution

# %% [markdown]
# Setup the driver

# %%
# Setup Chrome options
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")  # Run in headless mode
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--lang=en")  # Set browser language to English

# Initialize the WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

# %% [markdown]
# Retrieves the game list from the csv

# %%
# Top games data
top_games_df = pd.read_csv(TOP_GAMES_LIST_FILE)
games = top_games_df.loc[GAME_RANK_MIN-1:GAME_RANK_MAX-1, ['id', 'name']]

# Remove games already collected
if not OVERWRITE:
    try:
        with open(TOURNAMENTS_FILE, "r", encoding="utf-8") as f:
            data = json.load(f)
            collected_ids = [game["id"] for game in data]
            if collected_ids:
                games = games[~games['id'].isin(collected_ids)]
    except FileNotFoundError:
        pass
logger.warning(f"Games to collect: {len(games)}")
# Out:
# 2025-01-18 08:12:33,581 - WARNING - Games to collect: 1801

# %% [markdown]
# Retrieves the game list from the csv

# %%
saved_once = not OVERWRITE

# %%
all_data = []
i = 0
for name, game_id in tqdm(zip(games["name"], games["id"]), desc="Fetching forums", total=games.shape[0]):
    game = {
        "id": game_id,
        "name": name,
        "tournaments": []
    }
    
    # Find tournaments by game ID
    game_id = find_id_from_gamename(driver, name, sleep_time=REQUEST_DELAY, max_retries=MAX_RETRIES)
    if game_id is None:
        continue
    logger.warning(f'Fetching tournaments for "{name}" ({game_id})')

    # Find tournaments ids by game ID, in different statuses
    statuses=["future", "progress", "finished"]
    tournaments_ids = []
    for status in statuses:
        tournaments_status_ids = find_tournaments_by_id(
            game_id,
            status=status,
            ptime=4 if status=="future" else 0,
            max_tournaments_num=MAX_TOURNAMENTS_NUM, sleep_time=REQUEST_DELAY, max_retries=MAX_RETRIES
        )
        for tid in tournaments_status_ids:
            tournaments_ids.append({"id":tid,"status":status})
    logger.info(f'Fetching {len(tournaments_ids)} tournaments for "{name}" ({game_id})')

    tournaments = []
    for tournament in tournaments_ids:
            tournament_data = fetch_tournament_data(tournament["id"], tournament["status"], sleep_time=REQUEST_DELAY, max_retries=MAX_RETRIES)
            if tournament_data:
                tournaments.append(tournament_data)
    logger.info(f'Fetched tournaments data for "{name}".')

    # Add the tournaments to the game data
    game["tournaments"] = tournaments

    # Append the game data to the list
    all_data.append(game)

    i += 1
    if i % BACKUP_PERIOD == 0:
        # Save the data to the JSON file
        if not saved_once:
            # Save the data to the JSON file
            save_to_json(all_data, TOURNAMENTS_FILE)
            saved_once = True
        else:
            # Append the data to the JSON file
            append_to_json(all_data, TOURNAMENTS_FILE)
        logger.info(f"Saved {i} games into '{TOURNAMENTS_FILE}'")

        # Reset the data list
        all_data = []
    
if all_data:
    if not saved_once:
        # Save the data to the JSON file
        save_to_json(all_data, TOURNAMENTS_FILE)
    else:
        # Append the data to the JSON file
        append_to_json(all_data, TOURNAMENTS_FILE)
    logger.info(f"Saved remaining {len(all_data)} games forums into '{TOURNAMENTS_FILE}'")
# Out:
# Fetching forums:   0%|          | 2/2000 [00:02<32:17,  1.03it/s]  2025-01-18 02:09:38,224 - WARNING - Fetching tournaments for "Ark Nova" (1741)
# Fetching forums:   0%|          | 6/2000 [01:02<4:02:48,  7.31s/it] 2025-01-18 02:10:36,483 - WARNING - Fetching tournaments for "Terraforming Mars" (1924)
# Fetching forums:   1%|          | 11/2000 [02:21<3:54:31,  7.07s/it]2025-01-18 02:11:55,400 - WARNING - Fetching tournaments for "Gaia Project" (1495)
# Fetching forums:   1%|          | 15/2000 [03:13<3:56:21,  7.14s/it] 2025-01-18 02:12:47,036 - WARNING - Fetching tournaments for "Great Western Trail" (1432)
# Fetching forums:   1%|          | 16/2000 [04:59<20:27:09, 37.11s/it]2025-01-18 02:14:33,750 - WARNING - Fetching tournaments for "Scythe" (2032)
# Fetching forums:   1%|          | 18/2000 [05:04<10:29:53, 19.07s/it]2025-01-18 02:14:37,916 - WARNING - Fetching tournaments for "7 Wonders Duel" (1266)
# Fetching forums:   2%|▏         | 30/2000 [05:29<24:00,  1.37it/s]   2025-01-18 02:15:03,482 - WARNING - Fetching tournaments for "Terra Mystica" (1118)
# Fetching forums:   2%|▏         | 31/2000 [06:21<8:55:07, 16.31s/it]2025-01-18 02:15:56,145 - WARNING - Fetching tournaments for "Wingspan" (1635)
# Fetching forums:   2%|▏         | 35/2000 [07:09<4:53:30,  8.96s/it] 2025-01-18 02:16:43,910 - WARNING - Fetching tournaments for "Barrage" (1603)
# Fetching forums:   2%|▏         | 46/2000 [08:34<40:53,  1.26s/it]   2025-01-18 02:18:08,295 - WARNING - Fetching tournaments for "Sky Team" (1879)
# Fetching forums:   2%|▏         | 47/2000 [08:38<1:05:19,  2.01s/it]2025-01-18 02:18:12,099 - WARNING - Fetching tournaments for "Puerto Rico" (14)
# Fetching forums:   2%|▎         | 50/2000 [09:26<4:13:21,  7.80s/it]2025-01-18 02:18:59,933 - WARNING - Fetching tournaments for "Anachrony" (1717)
# Fetching forums:   3%|▎         | 53/2000 [10:01<4:19:40,  8.00s/it]2025-01-18 02:19:35,777 - WARNING - Fetching tournaments for "Blood Rage" (1521)
# Fetching forums:   3%|▎         | 54/2000 [10:39<9:07:37, 16.88s/it]2025-01-18 02:20:13,570 - WARNING - Fetching tournaments for "Agricola" (1430)
# Fetching forums:   3%|▎         | 62/2000 [10:46<45:50,  1.42s/it]  2025-01-18 02:20:20,480 - WARNING - Fetching tournaments for "Obsession" (1640)
# Fetching forums:   3%|▎         | 66/2000 [11:30<2:41:33,  5.01s/it]2025-01-18 02:21:04,783 - WARNING - Fetching tournaments for "Maracaibo" (1904)
# Fetching forums:   3%|▎         | 68/2000 [12:24<7:22:30, 13.74s/it] 2025-01-18 02:21:59,562 - WARNING - Fetching tournaments for "Clans of Caledonia" (1143)
# Fetching forums:   4%|▍         | 75/2000 [13:02<1:27:43,  2.73s/it] 2025-01-18 02:22:36,876 - WARNING - Fetching tournaments for "Age of Innovation" (1249)
# Fetching forums:   4%|▍         | 79/2000 [13:21<1:27:15,  2.73s/it]2025-01-18 02:22:56,337 - WARNING - Fetching tournaments for "Azul" (1467)
# Fetching forums:   4%|▍         | 80/2000 [14:14<9:21:49, 17.56s/it]2025-01-18 02:23:48,381 - WARNING - Fetching tournaments for "Race for the Galaxy" (10)
# Fetching forums:   4%|▍         | 89/2000 [14:58<55:47,  1.75s/it]   2025-01-18 02:24:32,437 - WARNING - Fetching tournaments for "Beyond the Sun" (1378)
# Fetching forums:   4%|▍         | 90/2000 [15:15<3:15:29,  6.14s/it]2025-01-18 02:24:49,009 - WARNING - Fetching tournaments for "El Grande" (1292)
# Fetching forums:   5%|▍         | 93/2000 [15:39<3:05:40,  5.84s/it]2025-01-18 02:25:13,471 - ERROR - Element with CSS selector "#game_id" not found for game "Revive" - error Message: no such element: Unable to locate element: {"method":"css selector","selector":"#game_id"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x0024D852]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
# .
# Fetching forums:   5%|▍         | 95/2000 [15:41<1:40:42,  3.17s/it]2025-01-18 02:25:15,218 - WARNING - Fetching tournaments for "7 Wonders" (1131)
# Fetching forums:   5%|▌         | 101/2000 [16:40<1:52:59,  3.57s/it]2025-01-18 02:26:14,474 - WARNING - Fetching tournaments for "Darwin's Journey" (2125)
# Fetching forums:   5%|▌         | 102/2000 [17:16<6:58:43, 13.24s/it]2025-01-18 02:26:50,823 - WARNING - Fetching tournaments for "Decrypto" (1771)
# Fetching forums:   5%|▌         | 107/2000 [17:22<1:28:01,  2.79s/it]2025-01-18 02:27:00,871 - WARNING - Fetching tournaments for "Architects of the West Kingdom" (1746)
# Fetching forums:   5%|▌         | 108/2000 [18:04<7:41:56, 14.65s/it]2025-01-18 02:27:38,432 - WARNING - Fetching tournaments for "Carnegie" (1287)
# Fetching forums:   6%|▌         | 111/2000 [18:35<5:05:08,  9.69s/it] 2025-01-18 02:28:09,400 - WARNING - Fetching tournaments for "Splendor Duel" (1903)
# Fetching forums:   6%|▌         | 112/2000 [19:36<13:12:51, 25.20s/it]2025-01-18 02:29:11,109 - WARNING - Fetching tournaments for "Keyflower" (1032)
# Fetching forums:   6%|▌         | 113/2000 [19:41<10:00:32, 19.10s/it]2025-01-18 02:29:15,851 - WARNING - Fetching tournaments for "Tigris & Euphrates" (1531)
# Fetching forums:   6%|▌         | 116/2000 [19:47<3:55:58,  7.51s/it] 2025-01-18 02:29:21,832 - WARNING - Fetching tournaments for "Caylus" (29)
# Fetching forums:   6%|▌         | 119/2000 [19:57<2:10:38,  4.17s/it]2025-01-18 02:29:31,916 - WARNING - Fetching tournaments for "Troyes" (20)
# Fetching forums:   6%|▋         | 127/2000 [20:06<26:51,  1.16it/s]  2025-01-18 02:29:40,473 - WARNING - Fetching tournaments for "Patchwork" (1420)
# Fetching forums:   6%|▋         | 130/2000 [20:12<40:20,  1.29s/it]  2025-01-18 02:29:46,167 - WARNING - Fetching tournaments for "Russian Railroads" (1086)
# Fetching forums:   7%|▋         | 145/2000 [20:23<12:06,  2.55it/s]  2025-01-18 02:29:57,227 - WARNING - Fetching tournaments for "Yokohama" (1161)
# Fetching forums:   7%|▋         | 146/2000 [20:58<5:32:09, 10.75s/it]2025-01-18 02:30:48,426 - WARNING - Fetching tournaments for "Harmonies" (2035)
# Fetching forums:   7%|▋         | 148/2000 [22:27<12:20:24, 23.99s/it]2025-01-18 02:32:01,278 - ERROR - Element with CSS selector "#game_id" not found for game "Champions of Midgard" - error Message: no such element: Unable to locate element: {"method":"css selector","selector":"#game_id"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x0024D852]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
# .
# Fetching forums:   7%|▋         | 149/2000 [22:28<8:50:56, 17.21s/it] 2025-01-18 02:32:02,430 - WARNING - Fetching tournaments for "Just One" (1533)
# Fetching forums:   8%|▊         | 150/2000 [22:32<6:44:17, 13.11s/it]2025-01-18 02:32:06,036 - WARNING - Fetching tournaments for "Roll for the Galaxy" (1115)
# Fetching forums:   8%|▊         | 154/2000 [22:48<2:32:36,  4.96s/it]2025-01-18 02:32:22,549 - WARNING - Fetching tournaments for "Pandemic" (1383)
# Fetching forums:   8%|▊         | 156/2000 [22:52<1:42:31,  3.34s/it]2025-01-18 02:32:26,629 - WARNING - Fetching tournaments for "The Isle of Cats" (1492)
# Fetching forums:   8%|▊         | 157/2000 [23:32<7:21:11, 14.36s/it]2025-01-18 02:33:06,922 - WARNING - Fetching tournaments for "Targi" (69)
# Fetching forums:   8%|▊         | 158/2000 [24:10<10:50:57, 21.20s/it]2025-01-18 02:33:44,300 - WARNING - Fetching tournaments for "Cartographers" (2030)
# Fetching forums:   8%|▊         | 159/2000 [25:24<19:01:27, 37.20s/it]2025-01-18 02:35:03,118 - WARNING - Fetching tournaments for "Hadrian's Wall" (1820)
# Fetching forums:   8%|▊         | 160/2000 [25:59<18:42:10, 36.59s/it]2025-01-18 02:35:33,631 - WARNING - Fetching tournaments for "Res Arcana" (1309)
# Fetching forums:   8%|▊         | 163/2000 [26:51<10:19:45, 20.24s/it]2025-01-18 02:36:25,248 - ERROR - Element with CSS selector "#game_id" not found for game "Watergate" - error Message: no such element: Unable to locate element: {"method":"css selector","selector":"#game_id"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x0024D852]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
# .
# Fetching forums:   8%|▊         | 165/2000 [26:53<5:13:31, 10.25s/it] 2025-01-18 02:36:26,853 - WARNING - Fetching tournaments for "It's a Wonderful World" (1594)
# Fetching forums:   8%|▊         | 167/2000 [28:07<10:31:18, 20.66s/it]2025-01-18 02:37:41,385 - WARNING - Fetching tournaments for "Ticket to Ride: Europe" (1900)
# Fetching forums:   9%|▊         | 173/2000 [29:17<3:08:28,  6.19s/it] 2025-01-18 02:38:51,935 - WARNING - Fetching tournaments for "Stone Age" (13)
# Fetching forums:   9%|▉         | 183/2000 [30:10<33:34,  1.11s/it]  2025-01-18 02:39:44,163 - WARNING - Fetching tournaments for "War Chest" (1619)
# Fetching forums:  10%|▉         | 192/2000 [31:02<37:00,  1.23s/it]  2025-01-18 02:40:36,739 - WARNING - Fetching tournaments for "Jaipur" (33)
# Fetching forums:  10%|▉         | 194/2000 [31:53<5:38:46, 11.25s/it]2025-01-18 02:41:27,424 - WARNING - Fetching tournaments for "Welcome To..." (1300)
# Fetching forums:  10%|▉         | 195/2000 [32:45<11:51:22, 23.65s/it]2025-01-18 02:42:22,062 - WARNING - Fetching tournaments for "Planet Unknown" (1891)
# Fetching forums:  10%|▉         | 196/2000 [33:20<13:33:08, 27.04s/it]2025-01-18 02:42:57,549 - WARNING - Fetching tournaments for "Earth" (1708)
# Fetching forums:  10%|█         | 208/2000 [34:24<31:34,  1.06s/it]   2025-01-18 02:43:58,800 - WARNING - Fetching tournaments for "Meadow" (1261)
# Fetching forums:  11%|█         | 213/2000 [34:30<21:00,  1.42it/s]2025-01-18 02:44:08,718 - WARNING - Fetching tournaments for "Space Base" (1428)
# Fetching forums:  11%|█         | 215/2000 [35:19<5:23:12, 10.86s/it]2025-01-18 02:44:54,018 - WARNING - Fetching tournaments for "Railways of the World" (1445)
# Fetching forums:  11%|█         | 216/2000 [36:12<11:30:42, 23.23s/it]2025-01-18 02:45:46,051 - WARNING - Fetching tournaments for "Azul: Summer Pavilion" (1911)
# Fetching forums:  11%|█         | 222/2000 [37:13<2:59:18,  6.05s/it] 2025-01-18 02:46:51,721 - ERROR - Element with CSS selector "#game_id" not found for game "Go" - error Message: no such element: Unable to locate element: {"method":"css selector","selector":"#game_id"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x0024D852]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
# .
# Fetching forums:  11%|█▏        | 228/2000 [37:20<38:02,  1.29s/it]  2025-01-18 02:46:59,618 - WARNING - Fetching tournaments for "Carcassonne" (1)
# Fetching forums:  12%|█▏        | 230/2000 [38:47<9:13:33, 18.76s/it] 2025-01-18 02:48:22,954 - WARNING - Fetching tournaments for "Splendor" (1394)
# Fetching forums:  12%|█▏        | 233/2000 [39:37<6:49:32, 13.91s/it] 2025-01-18 02:49:11,207 - WARNING - Fetching tournaments for "Tichu" (1237)
# 2025-01-18 02:49:38,483 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 02:49:39,961 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 02:49:43,002 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# Fetching forums:  12%|█▏        | 235/2000 [40:10<6:47:38, 13.86s/it]2025-01-18 02:49:44,682 - WARNING - Fetching tournaments for "Nidavellir" (1370)
# Fetching forums:  12%|█▏        | 246/2000 [40:54<27:36,  1.06it/s]   2025-01-18 02:50:28,513 - WARNING - Fetching tournaments for "Ticket to Ride" (1542)
# Fetching forums:  12%|█▏        | 249/2000 [41:43<3:41:24,  7.59s/it]2025-01-18 02:51:17,302 - WARNING - Fetching tournaments for "My City" (1659)
# Fetching forums:  13%|█▎        | 255/2000 [42:09<1:10:35,  2.43s/it]2025-01-18 02:51:43,770 - WARNING - Fetching tournaments for "La Granja" (1155)
# Fetching forums:  13%|█▎        | 262/2000 [42:16<20:09,  1.44it/s]  2025-01-18 02:51:50,284 - WARNING - Fetching tournaments for "Forest Shuffle" (1841)
# Fetching forums:  13%|█▎        | 263/2000 [43:29<10:48:00, 22.38s/it]2025-01-18 02:53:03,188 - WARNING - Fetching tournaments for "Hanamikoji" (1769)
# Fetching forums:  13%|█▎        | 267/2000 [44:08<4:36:46,  9.58s/it] 2025-01-18 02:53:42,932 - WARNING - Fetching tournaments for "Sushi Go Party!" (1561)
# Fetching forums:  14%|█▍        | 278/2000 [44:55<25:39,  1.12it/s]  2025-01-18 02:54:29,735 - WARNING - Fetching tournaments for "Santorini" (1196)
# Fetching forums:  14%|█▍        | 283/2000 [45:49<2:00:12,  4.20s/it]2025-01-18 02:55:24,035 - WARNING - Fetching tournaments for "Tapestry" (1446)
# Fetching forums:  14%|█▍        | 285/2000 [46:47<6:46:55, 14.24s/it]2025-01-18 02:56:26,756 - WARNING - Fetching tournaments for "Shogun" (1725)
# Fetching forums:  14%|█▍        | 290/2000 [47:03<1:45:05,  3.69s/it]2025-01-18 02:56:37,629 - WARNING - Fetching tournaments for "Viticulture" (1384)
# Fetching forums:  15%|█▍        | 299/2000 [48:09<48:45,  1.72s/it]  2025-01-18 02:57:43,470 - WARNING - Fetching tournaments for "Kingdomino" (1148)
# Fetching forums:  15%|█▌        | 308/2000 [48:18<18:36,  1.52it/s]  2025-01-18 02:57:52,104 - WARNING - Fetching tournaments for "Hive" (79)
# Fetching forums:  16%|█▌        | 314/2000 [48:25<21:09,  1.33it/s]2025-01-18 02:57:59,226 - ERROR - Element with CSS selector "#game_id" not found for game "Ethnos" - error Message: no such element: Unable to locate element: {"method":"css selector","selector":"#game_id"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x0024D852]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
# .
# Fetching forums:  16%|█▌        | 316/2000 [48:27<22:41,  1.24it/s]2025-01-18 02:58:01,583 - WARNING - Fetching tournaments for "Seasons" (30)
# Fetching forums:  16%|█▌        | 321/2000 [48:34<25:12,  1.11it/s]2025-01-18 02:58:08,308 - WARNING - Fetching tournaments for "Turing Machine" (1804)
# Fetching forums:  16%|█▋        | 327/2000 [48:41<22:07,  1.26it/s]2025-01-18 02:58:15,506 - WARNING - Fetching tournaments for "Distilled" (2008)
# Fetching forums:  16%|█▋        | 328/2000 [48:46<53:31,  1.92s/it]2025-01-18 02:58:19,981 - WARNING - Fetching tournaments for "Onitama" (1369)
# Fetching forums:  17%|█▋        | 331/2000 [48:51<45:17,  1.63s/it]  2025-01-18 02:58:25,978 - WARNING - Fetching tournaments for "Lost Cities" (9)
# Fetching forums:  17%|█▋        | 332/2000 [48:56<1:09:51,  2.51s/it]2025-01-18 02:58:30,197 - WARNING - Fetching tournaments for "Sea Salt & Paper" (1631)
# Fetching forums:  17%|█▋        | 333/2000 [49:00<1:24:31,  3.04s/it]2025-01-18 02:58:34,717 - WARNING - Fetching tournaments for "Dungeon Petz" (1284)
# Fetching forums:  17%|█▋        | 334/2000 [49:05<1:35:30,  3.44s/it]2025-01-18 02:58:39,004 - WARNING - Fetching tournaments for "Love Letter" (1044)
# Fetching forums:  17%|█▋        | 336/2000 [49:10<1:16:54,  2.77s/it]2025-01-18 02:58:44,161 - WARNING - Fetching tournaments for "For Sale" (1146)
# Fetching forums:  18%|█▊        | 350/2000 [49:21<15:58,  1.72it/s]  2025-01-18 02:58:55,660 - WARNING - Fetching tournaments for "Love Letter" (1044)
# Fetching forums:  18%|█▊        | 351/2000 [49:26<46:24,  1.69s/it]2025-01-18 02:59:00,189 - WARNING - Fetching tournaments for "Glass Road" (1961)
# Fetching forums:  18%|█▊        | 354/2000 [49:31<42:09,  1.54s/it]  2025-01-18 02:59:05,867 - WARNING - Fetching tournaments for "Tikal" (2005)
# Fetching forums:  18%|█▊        | 355/2000 [49:36<1:07:30,  2.46s/it]2025-01-18 02:59:10,463 - WARNING - Fetching tournaments for "Bunny Kingdom" (1747)
# Fetching forums:  19%|█▊        | 372/2000 [49:50<15:47,  1.72it/s]  2025-01-18 02:59:24,439 - WARNING - Fetching tournaments for "Small World" (2016)
# Fetching forums:  19%|█▊        | 373/2000 [49:55<53:37,  1.98s/it]2025-01-18 02:59:29,142 - WARNING - Fetching tournaments for "Burgle Bros." (1412)
# Fetching forums:  19%|█▉        | 379/2000 [50:00<19:01,  1.42it/s]  2025-01-18 02:59:34,232 - ERROR - Element with CSS selector "#game_id" not found for game "Arboretum" - error Message: no such element: Unable to locate element: {"method":"css selector","selector":"#game_id"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x0024D852]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
# .
# Fetching forums:  19%|█▉        | 380/2000 [50:01<21:09,  1.28it/s]2025-01-18 02:59:35,337 - WARNING - Fetching tournaments for "Innovation" (1113)
# Fetching forums:  20%|█▉        | 393/2000 [50:49<19:26,  1.38it/s]  2025-01-18 03:00:23,257 - WARNING - Fetching tournaments for "Gizmos" (1670)
# Fetching forums:  20%|█▉        | 397/2000 [50:55<26:44,  1.00s/it]2025-01-18 03:00:29,409 - WARNING - Fetching tournaments for "Takenoko" (37)
# Fetching forums:  20%|██        | 401/2000 [51:01<29:29,  1.11s/it]2025-01-18 03:00:40,716 - WARNING - Fetching tournaments for "Ginkgopolis" (1166)
# Fetching forums:  20%|██        | 405/2000 [51:12<42:09,  1.59s/it]  2025-01-18 03:00:47,047 - WARNING - Fetching tournaments for "Faraway" (1868)
# Fetching forums:  20%|██        | 410/2000 [51:19<27:37,  1.04s/it]  2025-01-18 03:00:56,757 - WARNING - Fetching tournaments for "Abyss" (1335)
# Fetching forums:  21%|██        | 423/2000 [51:32<10:06,  2.60it/s]  2025-01-18 03:01:07,486 - WARNING - Fetching tournaments for "Newton" (2001)
# Fetching forums:  21%|██        | 424/2000 [51:41<1:17:34,  2.95s/it]2025-01-18 03:01:14,921 - WARNING - Fetching tournaments for "The Guild of Merchant Explorers" (2216)
# Fetching forums:  22%|██▏       | 430/2000 [51:46<21:21,  1.23it/s]  2025-01-18 03:01:20,329 - WARNING - Fetching tournaments for "Expeditions" (1794)
# Fetching forums:  22%|██▏       | 436/2000 [52:22<54:26,  2.09s/it]  2025-01-18 03:01:56,421 - WARNING - Fetching tournaments for "Saint Petersburg" (1227)
# Fetching forums:  22%|██▏       | 440/2000 [52:59<1:55:33,  4.44s/it]2025-01-18 03:02:33,627 - WARNING - Fetching tournaments for "King of Tokyo" (1439)
# Fetching forums:  22%|██▏       | 442/2000 [53:59<6:22:11, 14.72s/it]2025-01-18 03:03:33,226 - WARNING - Fetching tournaments for "Downforce" (1195)
# Fetching forums:  22%|██▏       | 445/2000 [54:38<4:43:08, 10.92s/it]2025-01-18 03:04:12,498 - WARNING - Fetching tournaments for "Dice Forge" (1127)
# Fetching forums:  22%|██▏       | 447/2000 [55:32<7:11:05, 16.66s/it] 2025-01-18 03:05:06,276 - WARNING - Fetching tournaments for "Chess" (81)
# 2025-01-18 03:05:11,600 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:05:14,923 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:05:22,007 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:05:23,212 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:05:26,345 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# Fetching forums:  22%|██▏       | 448/2000 [55:53<7:47:23, 18.07s/it]2025-01-18 03:05:27,760 - WARNING - Fetching tournaments for "In the Year of the Dragon" (26)
# Fetching forums:  22%|██▏       | 449/2000 [56:15<8:12:16, 19.04s/it]2025-01-18 03:05:49,000 - WARNING - Fetching tournaments for "Skull" (1371)
# Fetching forums:  22%|██▎       | 450/2000 [56:40<8:58:18, 20.84s/it]2025-01-18 03:06:14,038 - WARNING - Fetching tournaments for "Akropolis" (1768)
# Fetching forums:  24%|██▍       | 485/2000 [57:42<08:49,  2.86it/s]   2025-01-18 03:07:16,502 - WARNING - Fetching tournaments for "Stockpile" (1743)
# Fetching forums:  24%|██▍       | 488/2000 [57:47<21:08,  1.19it/s]2025-01-18 03:07:21,012 - WARNING - Fetching tournaments for "Nippon" (1080)
# Fetching forums:  25%|██▍       | 496/2000 [58:16<25:40,  1.02s/it]  2025-01-18 03:07:50,103 - WARNING - Fetching tournaments for "Mandala" (1940)
# Fetching forums:  25%|██▌       | 507/2000 [58:53<16:03,  1.55it/s]  2025-01-18 03:08:27,263 - WARNING - Fetching tournaments for "Caper: Europe" (1656)
# Fetching forums:  25%|██▌       | 508/2000 [59:13<2:42:00,  6.51s/it]2025-01-18 03:08:46,981 - ERROR - Element with CSS selector "#game_id" not found for game "Lancaster" - error Message: no such element: Unable to locate element: {"method":"css selector","selector":"#game_id"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x0024D852]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
# .
# Fetching forums:  26%|██▌       | 510/2000 [59:14<1:27:02,  3.50s/it]2025-01-18 03:08:48,484 - ERROR - Element with CSS selector "#game_id" not found for game "Pipeline" - error Message: no such element: Unable to locate element: {"method":"css selector","selector":"#game_id"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x0024D852]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
# .
# Fetching forums:  26%|██▌       | 518/2000 [59:18<13:22,  1.85it/s]  2025-01-18 03:08:57,044 - WARNING - Fetching tournaments for "Colt Express" (1025)
# Fetching forums:  26%|██▌       | 520/2000 [59:51<3:01:17,  7.35s/it]2025-01-18 03:09:25,718 - WARNING - Fetching tournaments for "No Thanks!" (1299)
# Fetching forums:  26%|██▌       | 521/2000 [1:00:14<4:52:45, 11.88s/it]2025-01-18 03:09:48,122 - WARNING - Fetching tournaments for "Citadels" (1503)
# Fetching forums:  26%|██▌       | 523/2000 [1:00:18<2:45:34,  6.73s/it]2025-01-18 03:09:52,344 - WARNING - Fetching tournaments for "Hadara" (1755)
# Fetching forums:  26%|██▋       | 525/2000 [1:00:52<4:17:34, 10.48s/it]2025-01-18 03:10:26,300 - ERROR - Element with CSS selector "#game_id" not found for game "Bohnanza" - error Message: no such element: Unable to locate element: {"method":"css selector","selector":"#game_id"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x0024D852]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
# .
# Fetching forums:  27%|██▋       | 533/2000 [1:00:56<23:16,  1.05it/s]  2025-01-18 03:10:29,781 - WARNING - Fetching tournaments for "Citadels" (1503)
# Fetching forums:  27%|██▋       | 535/2000 [1:01:00<32:35,  1.33s/it]2025-01-18 03:10:34,077 - WARNING - Fetching tournaments for "Canvas" (1833)
# Fetching forums:  27%|██▋       | 538/2000 [1:01:29<1:59:14,  4.89s/it]2025-01-18 03:11:03,275 - ERROR - Element with CSS selector "#game_id" not found for game "Amerigo" - error Message: no such element: Unable to locate element: {"method":"css selector","selector":"#game_id"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x0024D852]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
# .
# Fetching forums:  27%|██▋       | 545/2000 [1:01:32<18:00,  1.35it/s]  2025-01-18 03:11:06,739 - WARNING - Fetching tournaments for "Hanabi" (1015)
# 2025-01-18 03:11:10,955 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:11:12,496 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:11:13,650 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:11:15,035 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:11:18,055 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:11:19,353 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:11:20,614 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:11:21,884 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# Fetching forums:  27%|██▋       | 549/2000 [1:01:51<55:03,  2.28s/it]  2025-01-18 03:11:26,093 - WARNING - Fetching tournaments for "Potion Explosion" (1175)
# Fetching forums:  28%|██▊       | 554/2000 [1:02:55<2:03:33,  5.13s/it]2025-01-18 03:12:29,695 - WARNING - Fetching tournaments for "Deus" (1481)
# Fetching forums:  28%|██▊       | 564/2000 [1:03:26<19:44,  1.21it/s]  2025-01-18 03:13:00,246 - WARNING - Fetching tournaments for "Imhotep" (1493)
# Fetching forums:  28%|██▊       | 565/2000 [1:03:51<3:15:45,  8.18s/it]2025-01-18 03:13:25,461 - WARNING - Fetching tournaments for "CATAN" (1539)
# Fetching forums:  28%|██▊       | 567/2000 [1:04:21<4:05:22, 10.27s/it]2025-01-18 03:13:55,377 - WARNING - Fetching tournaments for "Thurn and Taxis" (1238)
# Fetching forums:  28%|██▊       | 570/2000 [1:04:59<3:39:32,  9.21s/it]2025-01-18 03:14:33,113 - ERROR - Element with CSS selector "#game_id" not found for game "Raptor" - error Message: no such element: Unable to locate element: {"method":"css selector","selector":"#game_id"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# ...
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:40:06,153 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:40:07,397 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:40:08,881 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:40:10,369 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:40:11,841 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# Fetching forums:  55%|█████▍    | 1094/2000 [1:30:44<05:48,  2.60it/s]  2025-01-18 03:40:18,704 - WARNING - Fetching tournaments for "CuBirds" (1210)
# Fetching forums:  55%|█████▌    | 1102/2000 [1:31:19<16:34,  1.11s/it]  2025-01-18 03:40:53,201 - WARNING - Fetching tournaments for "Quarto" (39)
# Fetching forums:  56%|█████▌    | 1114/2000 [1:32:06<08:44,  1.69it/s]  2025-01-18 03:41:40,026 - ERROR - Element with CSS selector "#game_id" not found for game "Mr. Jack Pocket" - error Message: no such element: Unable to locate element: {"method":"css selector","selector":"#game_id"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x0024D852]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
# .
# Fetching forums:  56%|█████▌    | 1121/2000 [1:32:09<05:37,  2.60it/s]2025-01-18 03:41:43,388 - WARNING - Fetching tournaments for "Oriflamme" (1328)
# Fetching forums:  56%|█████▋    | 1130/2000 [1:32:37<11:18,  1.28it/s]  2025-01-18 03:42:11,628 - WARNING - Fetching tournaments for "Super Fantasy Brawl" (1360)
# Fetching forums:  57%|█████▋    | 1140/2000 [1:33:10<10:22,  1.38it/s]  2025-01-18 03:42:44,122 - WARNING - Fetching tournaments for "Jump Drive" (1592)
# Fetching forums:  57%|█████▋    | 1141/2000 [1:33:39<2:14:29,  9.39s/it]2025-01-18 03:43:13,791 - WARNING - Fetching tournaments for "Automobiles" (1268)
# Fetching forums:  58%|█████▊    | 1155/2000 [1:33:48<06:03,  2.33it/s]  2025-01-18 03:43:22,337 - WARNING - Fetching tournaments for "Haggis" (16)
# Fetching forums:  58%|█████▊    | 1160/2000 [1:34:18<33:29,  2.39s/it]  2025-01-18 03:43:52,373 - WARNING - Fetching tournaments for "Resist!" (2190)
# Fetching forums:  59%|█████▊    | 1171/2000 [1:34:25<05:59,  2.31it/s]2025-01-18 03:43:59,559 - ERROR - Element with CSS selector "#game_id" not found for game "Pirates of Maracaibo" - error Message: no such element: Unable to locate element: {"method":"css selector","selector":"#game_id"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x0024D852]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
# .
# Fetching forums:  59%|█████▉    | 1176/2000 [1:34:28<05:50,  2.35it/s]2025-01-18 03:44:02,623 - WARNING - Fetching tournaments for "Rats of Wistar" (2200)
# Fetching forums:  59%|█████▉    | 1180/2000 [1:34:33<11:04,  1.23it/s]2025-01-18 03:44:07,724 - WARNING - Fetching tournaments for "Hardback" (1354)
# 2025-01-18 03:44:19,881 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:44:23,327 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:44:24,752 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:44:25,992 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# 2025-01-18 03:44:27,157 - ERROR - Exception occurred while retrieving tournament details: Message: no such element: Unable to locate element: {"method":"xpath","selector":"div[2]/span/div"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0036FD53+23747]
# 	(No symbol) [0x002F7D54]
# 	(No symbol) [0x001CBE53]
# 	(No symbol) [0x0020FCA6]
# 	(No symbol) [0x0020FEEB]
# 	(No symbol) [0x00205A81]
# 	(No symbol) [0x00231E44]
# 	(No symbol) [0x002059A4]
# 	(No symbol) [0x00232094]
# 	(No symbol) [0x0024B41E]
# 	(No symbol) [0x00231B96]
# 	(No symbol) [0x00203F3C]
# 	(No symbol) [0x00204EBD]
# 	GetHandleVerifier [0x0064AC73+3017699]
# 	GetHandleVerifier [0x0065B93B+3086507]
# 	GetHandleVerifier [0x006540F2+3055714]
# 	GetHandleVerifier [0x00405AF0+637536]
# 	(No symbol) [0x00300A5D]
# 	(No symbol) [0x002FDA28]
# 	(No symbol) [0x002FDBC5]
# 	(No symbol) [0x002F07F0]
# 	BaseThreadInitThunk [0x75FD7BA9+25]
# 	RtlInitializeExceptionChain [0x7754C0CB+107]
# 	RtlClearBits [0x7754C04F+191]
#
# Fetching forums:  60%|█████▉    | 1190/2000 [1:34:57<08:09,  1.66it/s]  2025-01-18 03:44:31,797 - WARNING - Fetching tournaments for "Rallyman: GT" (1179)
# Fetching forums:  63%|██████▎   | 1258/2000 [1:35:56<04:11,  2.95it/s]  2025-01-18 03:45:30,990 - WARNING - Fetching tournaments for "Chimera Station" (1522)
# Fetching forums:  64%|██████▎   | 1270/2000 [1:36:04<04:26,  2.74it/s]2025-01-18 03:45:38,705 - WARNING - Fetching tournaments for "Diamonds" (2078)
# Fetching forums:  64%|██████▍   | 1290/2000 [1:36:14<04:07,  2.87it/s]2025-01-18 03:45:48,580 - WARNING - Fetching tournaments for "Mini Rogue" (1966)
# Fetching forums: 100%|██████████| 2000/2000 [1:38:33<00:00,  2.96s/it]
